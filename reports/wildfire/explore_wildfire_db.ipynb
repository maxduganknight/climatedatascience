# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gpkg_path = '../../data/UNSEEN/wildfire/usda_fire_db/FPA_FOD_20221014.gpkg'

sql = "SELECT * FROM Fires WHERE STATE = 'MN' AND CONT_DATE = '08/01/2020"

gdf = gpd.read_file(gpkg_path, sql=sql)
print(gdf.head())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 gpkg_path = '../../data/UNSEEN/wildfire/usda_fire_db/FPA_FOD_20221014.gpkg'
#       3 sql = "SELECT * FROM Fires WHERE STATE = 'MN' AND CONT_DATE = '08/01/2020"
# ----> 5 gdf = gpd.read_file(gpkg_path, sql=sql)
#       6 print(gdf.head())
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/geopandas/io/file.py:289, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     286     else:
#     287         path_or_bytes = filename
# --> 289     return _read_file_fiona(
#     290         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     291     )
#     293 else:
#     294     raise ValueError(f"unknown engine '{engine}'")
#
# ...
